# %%
import torch
import numpy as np

# %%
words=open('names.txt', 'r').read().splitlines()
words[:20]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn',
#  'abigail',
#  'emily',
#  'elizabeth',
#  'mila',
#  'ella',
#  'avery',
#  'sofia',
#  'camila',
#  'aria',
#  'scarlett']

# %%
len(words)
# Out:
# 32033

# %%
min(len(word) for word in words)
# Out:
# 2

# %%
list=[]
for w in words:
    for ch1, ch2 in zip(w, w[1:]):
        list.append((ch1, ch2))
list[0:20]
sorted(list)
# Out:
# [('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
# ...
